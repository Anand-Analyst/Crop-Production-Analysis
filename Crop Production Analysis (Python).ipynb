# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ***Loading Dataset***

# %%
crop_df=pd.read_csv("../Documents/Project_Datasets/crop_production.csv")

# %%
crop_df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
crop_df.shape
# Out:
# (246091, 7)

# %%
crop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# **Checking For Missing Values**

# %%
# Checking the null values count from dataset
crop_df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
#Dropping null values rows from dataset
crop_df.dropna(inplace=True)

# %%
#After dropping  null values
crop_df.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
crop_df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %% [markdown]
# **Variable Analysis**

# %% [markdown]
# *State Variable*

# %%
crop_df.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
crop_df.State_Name.nunique()
# Out:
# 33

# %%
crop_df.State_Name.value_counts()
# Out:
# State_Name
# Uttar Pradesh                  33189
# Madhya Pradesh                 22604
# Karnataka                      21079
# Bihar                          18874
# Assam                          14622
# Odisha                         13524
# Tamil Nadu                     13266
# Maharashtra                    12496
# Rajasthan                      12066
# Chhattisgarh                   10368
# West Bengal                     9597
# Andhra Pradesh                  9561
# Gujarat                         8365
# Telangana                       5591
# Uttarakhand                     4825
# Haryana                         4540
# Kerala                          4003
# Nagaland                        3904
# Punjab                          3143
# Meghalaya                       2867
# Arunachal Pradesh               2545
# Himachal Pradesh                2456
# Jammu and Kashmir               1632
# Tripura                         1412
# Manipur                         1266
# ...

# %% [markdown]
# **District Variable**

# %%
crop_df.District_Name.nunique()
# Out:
# 646

# %%
crop_df.District_Name.unique()
# Out:
# array(['NICOBARS', 'NORTH AND MIDDLE ANDAMAN', 'SOUTH ANDAMANS',
#        'ANANTAPUR', 'CHITTOOR', 'EAST GODAVARI', 'GUNTUR', 'KADAPA',
#        'KRISHNA', 'KURNOOL', 'PRAKASAM', 'SPSR NELLORE', 'SRIKAKULAM',
#        'VISAKHAPATANAM', 'VIZIANAGARAM', 'WEST GODAVARI', 'ANJAW',
#        'CHANGLANG', 'DIBANG VALLEY', 'EAST KAMENG', 'EAST SIANG',
#        'KURUNG KUMEY', 'LOHIT', 'LONGDING', 'LOWER DIBANG VALLEY',
#        'LOWER SUBANSIRI', 'NAMSAI', 'PAPUM PARE', 'TAWANG', 'TIRAP',
#        'UPPER SIANG', 'UPPER SUBANSIRI', 'WEST KAMENG', 'WEST SIANG',
#        'BAKSA', 'BARPETA', 'BONGAIGAON', 'CACHAR', 'CHIRANG', 'DARRANG',
#        'DHEMAJI', 'DHUBRI', 'DIBRUGARH', 'DIMA HASAO', 'GOALPARA',
#        'GOLAGHAT', 'HAILAKANDI', 'JORHAT', 'KAMRUP', 'KAMRUP METRO',
#        'KARBI ANGLONG', 'KARIMGANJ', 'KOKRAJHAR', 'LAKHIMPUR', 'MARIGAON',
#        'NAGAON', 'NALBARI', 'SIVASAGAR', 'SONITPUR', 'TINSUKIA',
#        'UDALGURI', 'ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BEGUSARAI',
# ...

# %%
crop_df.District_Name.value_counts()
# Out:
# District_Name
# TUMKUR       931
# BELGAUM      924
# BIJAPUR      905
# HASSAN       895
# BELLARY      887
#             ...
# HYDERABAD      8
# KHUNTI         6
# RAMGARH        6
# NAMSAI         1
# MUMBAI         1
# Name: count, Length: 646, dtype: int64

# %% [markdown]
# **Crop Year Variable**

# %%
print("Total Unique years:",crop_df.Crop_Year.nunique())
print("Min year:",crop_df.Crop_Year.min())
print("Max year:",crop_df.Crop_Year.max())
print(crop_df.Crop_Year.value_counts())
# Out:
# Total Unique years: 19
# Min year: 1997
# Max year: 2015
# Crop_Year
# 2003    17139
# 2002    16536
# 2007    14269
# 2008    14230
# 2006    13976
# 2004    13858
# 2010    13793
# 2011    13791
# 2009    13767
# 2000    13553
# 2005    13519
# 2013    13475
# 2001    13293
# 2012    13184
# 1999    12441
# 1998    11262
# 2014    10815
# 1997     8899
# 2015      561
# Name: count, dtype: int64

# %% [markdown]
# **Season Variable**

# %%
print(crop_df.Season.nunique())
print(crop_df.Season.unique())
print(crop_df.Season.max())
print(crop_df.Season.value_counts())
# Out:
# 6
# ['Kharif     ' 'Whole Year ' 'Autumn     ' 'Rabi       ' 'Summer     '
#  'Winter     ']
# Winter
# Season
# Kharif         94283
# Rabi           66160
# Whole Year     56127
# Summer         14811
# Winter          6050
# Autumn          4930
# Name: count, dtype: int64

# %%
print("Total Unique crops:",crop_df.Crop.nunique())
print(crop_df.Crop.unique())
print(crop_df.Crop.max())
print(crop_df.Crop.value_counts().head(20))
# Out:
# Total Unique crops: 124
# ['Arecanut' 'Other Kharif pulses' 'Rice' 'Banana' 'Cashewnut' 'Coconut '
#  'Dry ginger' 'Sugarcane' 'Sweet potato' 'Tapioca' 'Black pepper'
#  'Dry chillies' 'other oilseeds' 'Turmeric' 'Maize' 'Moong(Green Gram)'
#  'Urad' 'Arhar/Tur' 'Groundnut' 'Sunflower' 'Bajra' 'Castor seed'
#  'Cotton(lint)' 'Horse-gram' 'Jowar' 'Korra' 'Ragi' 'Tobacco' 'Gram'
#  'Wheat' 'Masoor' 'Sesamum' 'Linseed' 'Safflower' 'Onion'
#  'other misc. pulses' 'Samai' 'Small millets' 'Coriander' 'Potato'
#  'Other  Rabi pulses' 'Soyabean' 'Beans & Mutter(Vegetable)' 'Bhindi'
#  'Brinjal' 'Citrus Fruit' 'Cucumber' 'Grapes' 'Mango' 'Orange'
#  'other fibres' 'Other Fresh Fruits' 'Other Vegetables' 'Papaya'
#  'Pome Fruit' 'Tomato' 'Mesta' 'Cowpea(Lobia)' 'Lemon' 'Pome Granet'
#  'Sapota' 'Cabbage' 'Rapeseed &Mustard' 'Peas  (vegetable)' 'Niger seed'
#  'Bottle Gourd' 'Varagu' 'Garlic' 'Ginger' 'Oilseeds total' 'Pulses total'
# ...

# %% [markdown]
# **Area Variable**

# %%
print("Total Unique Area:",crop_df.Area.nunique())
print("Max Area:",crop_df.Area.max())
print(crop_df.Area.value_counts().head(10))
print(crop_df.Area.value_counts().tail(10))
# Out:
# Total Unique Area: 38391
# Max Area: 8580100.0
# Area
# 1.0      3573
# 2.0      3140
# 100.0    2621
# 3.0      2478
# 4.0      2182
# 5.0      2090
# 6.0      1750
# 200.0    1671
# 10.0     1590
# 7.0      1555
# Name: count, dtype: int64
# Area
# 63107.0     1
# 13655.0     1
# 95399.0     1
# 71644.0     1
# 17459.0     1
# 25569.0     1
# 19349.0     1
# 90302.0     1
# 39698.0     1
# 279151.0    1
# Name: count, dtype: int64

# %% [markdown]
# **Production Variable**

# %%
crop_df.Production.describe()
# Out:
# count    2.423610e+05
# mean     5.825034e+05
# std      1.706581e+07
# min      0.000000e+00
# 25%      8.800000e+01
# 50%      7.290000e+02
# 75%      7.023000e+03
# max      1.250800e+09
# Name: Production, dtype: float64

# %%
crop_df.Production.value_counts(ascending = False)
# Out:
# Production
# 1.000000e+00    4028
# 0.000000e+00    3523
# 1.000000e+02    3521
# 2.000000e+00    2964
# 3.000000e+00    2311
#                 ...
# 2.120000e+08       1
# 1.070000e+00       1
# 2.293410e+05       1
# 1.870600e+04       1
# 5.978990e+05       1
# Name: count, Length: 51627, dtype: int64

# %%
crop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242361 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     242361 non-null  object
#  1   District_Name  242361 non-null  object
#  2   Crop_Year      242361 non-null  int64
#  3   Season         242361 non-null  object
#  4   Crop           242361 non-null  object
#  5   Area           242361 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 14.8+ MB

# %% [markdown]
# **Production Distribution**

# %%
plt.boxplot(crop_df.Production)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x174a5b3fd70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x174a5af78c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x174a5b9b8c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x174a5c25d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x174a5c26030>],
#  'means': []}

# %% [markdown]
# **State Wise Production**

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=crop_df['Production'],y= crop_df["State_Name"], orient='h');
plt.title('State wise Production')
# Out:
# Text(0.5, 1.0, 'State wise Production')

# %% [markdown]
# **Zone Wise Production - 1997-2014**

# %%
north_india = ['Jammu and Kashmir','Punjab','Himanchal Pradesh','Haryana','Uttrakhand','Uttar Pradesh','Chandigarh']
east_india = ['Bihar','Odisha','Jharkhand','West Bengal']
south_india = ['Anadhra Pradesh','Karnataka','Kerala','Tamil Nadu','Telangana']
west_inida = ['Rajasthan','Gujarat','Goa','Maharashtra']
central_india = ['Madhya Pradesh','Chattishgarh']
north_east_india = ['Assam','Sikkim','Nagaland','Meghalaya','Manipur','Mizoram','Tripura','Arunachal Pradesh']
ut_india = ['Andaman and Nicobar Islands','Dadra and Nagar Haveli','Puducherry']

# %%
def get_zonal_names(row):
    if row['State_Name'].strip()  in north_india:
        val = 'North Zone'
    elif row['State_Name'].strip() in south_india:
        val = 'South Zone'
    elif row['State_Name'].strip() in east_india:
         val = 'East Zone'
    elif row['State_Name'].strip() in west_india:
         val = 'West Zone'
    elif row['State_Name'].strip() in central_india:
          val = 'NE Zone'
    elif row['State_Name'].strip() in north_east_india:
         val = 'Union Terr'
    else:
        val = 'No Value'
    return val
crop_df['Zones'] = crop_df.apply(get_zonal_names, axis=1)
print(crop_df['Zones'].unique())
# Out:
# ['No Value' 'Union Terr' 'East Zone' 'North Zone' 'NE Zone' 'West Zone'
#  'South Zone']

# %%
crop_df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production     Zones
# 0             Arecanut  1254.0      2000.0  No Value
# 1  Other Kharif pulses     2.0         1.0  No Value
# 2                 Rice   102.0       321.0  No Value
# 3               Banana   176.0       641.0  No Value
# 4            Cashewnut   720.0       165.0  No Value

# %%
data_explorer = crop_df.copy()

# %% [markdown]
# **Zonal Distribution of Crops**

# %%
fig,ax = plt.subplots(figsize=(10,10))
sns.barplot(x=crop_df['Zones'], y=crop_df['Production'])
plt.title('Zone-Wise Production: Total')
plt.xlabel('Zones')
plt.ylabel('Production')
plt.yscale('log')
plt.show()

# %%
south_zone = crop_df[(crop_df["Zones"] == 'South Zone')]
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x=south_zone.State_Name, y=south_zone.Production)  # Corrected from State_name to State_Name
plt.yscale('log')
plt.title('Southern-Zone Production')
plt.xlabel('State Name')
plt.ylabel('Production')
plt.show()

# %%
crop=crop_df['Crop']
def cat_crop(crop):
    for i in ['Rice','Maize','Wheat','Barley','Varagu','Other Cereals&Millets','Ragi','Small millets','Bajra','Jowar','Paddy','Total foodgrain','Jobster']:
        if crop==i:
            return 'Cereal'
    for i in ['Moong','Urad','Arhar/Tur','Peas&Beans','Masoor',
             'Other Kharif pulses','Other Misc Pulses','Ricebean(nagadal',
             'Rajmash Kholar', 'Lentil','Samai','Blackgram','Korra','Cowpea(Lobia)',
             'Other Rabi Pulses','Other Kharif Pulses','Peas & Beans(pulses)','Pulses total','Gram']:
       if  crop==i:
         return 'Pulses'
    for i in ['Peaches','Apple','Litchi','Pear','Plums','Ber','Sapota','Lemon',
             'Other Citrus  Fruits','Watermelon','Grapes',
             'pome fruit','Citrus fruit','Other Fresh Fruits','Mango']:
       if crop==i:
           return 'Beans'
    for i in ['Turnip','Peas','Beet Root','Carrot','Yam',
                     'Bitter guard','Cucumber','Drum Stick',
                     'Bhindi','Tomato']:
       if crop==i:
           return 'Fruits'
    for i in ['Moth','Soyabean','Horse gram']:
       if crop==i:
           return'Vegetables'
    for i in ['Perilla','Ginger','Cardamom','Black pepper','Dry Ginger']:
       if crop==i:
           return'Spices'
    for i in ['other fibres','kapas','Jute','Mesta','Cotton']:
       if crop==i:
           return 'fibres'
    for i in ['Arcanut','Cashewnut Raw','Arecanut']:
       if crop==i:
           return 'Nuts'
    for i in ['other oilseeds','Safflover','Niger Seed','Sunflower']:
       if crop==i:
           return'Oilseeds'
    for i in ['Tobacco','Coffee','Tea']:
       if crop==i:
           return'Commercial'

# %%
crop_df['cat_crop']=crop_df['Crop'].apply(cat_crop)

# %%
crop_df["cat_crop"].value_counts()
# Out:
# cat_crop
# Unknown       125388
# Cereal         62675
# Pulses         33286
# Oilseeds        6077
# Vegetables      3967
# fibres          3188
# Commercial      2705
# Nuts            1573
# Spices          1506
# Beans           1099
# Fruits           897
# Name: count, dtype: int64

# %% [markdown]
# **Overall Crops vs Production**

# %%
crop = data_explorer.groupby(by='Crop')['Production'].sum().reset_index().sort_values(by='Production',ascending=False).head(10)
fig,ax = plt.subplots(figsize=(15,10))
sns.barplot(x=crop.Crop, y=crop.Production)
plt.yscale('log')
plt.title('Overall crop vs production')
# Out:
# Text(0.5, 1.0, 'Overall crop vs production')

# %% [markdown]
# **Year Wise Production**

# %%
fig,ax = plt.subplots(figsize=(15,10))
plt.tick_params(labelsize=10)
data_explorer.groupby("Crop_Year")["Production"].agg("sum").plot.bar()
plt.title('Year-wise Production')
# Out:
# Text(0.5, 1.0, 'Year-wise Production')

# %% [markdown]
# **Season Wise Production**

# %%
df_season=data_explorer.copy()
season = df_season.groupby(by='Season')['Production'].sum().reset_index().sort_values(by='Production',ascending=False).head(10)
season
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x=season.Season, y=season.Production)
plt.yscale('log')
plt.title('Seasonal Crops vs Production')
# Out:
# Text(0.5, 1.0, 'Seasonal Crops vs Production')

# %% [markdown]
# **Category Crop vs Production**

# %%
plt.figure(figsize=(15,8))
plt.tick_params(labelsize=10)
crop_df.groupby('cat_crop')["Production"].agg("count").plot.bar()
plt.title('Category Crop vs Production')
plt.show()

# %% [markdown]
# **State vs Category Crop vs Season Plot**

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=crop_df,x="State_Name",y="cat_crop",hue="Season")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\com-tech computer\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **Different proportion of Crop Categories of India**

# %%
df1=crop_df["cat_crop"].value_counts()
df1.plot(radius=3,kind="pie",autopct="%1.1f",pctdistance=0.6)
plt.tick_params(labelsize=10)

# %%
#Answering Q/A

# %% [markdown]
# **Q1: Which States dominates in crop production with different categories of crops**

# %%
df_2=pd.crosstab(data_explorer['State_Name'],crop_df['cat_crop'])
df_2
# Out:
# cat_crop                     Beans  Cereal  Commercial  Fruits  Nuts  \
# State_Name
# Andaman and Nicobar Islands      0      20           0       0    17
# Andhra Pradesh                 186    2264         242     154    41
# Arunachal Pradesh                0    1021           0       0     0
# Assam                            0    2952         400       0   400
# Bihar                            0    6108         211       0     0
# Chandigarh                       0      39           0       0     0
# Chhattisgarh                     0    1805          56       0     0
# Dadra and Nagar Haveli           0     116           0       0     0
# Goa                              8      62           0       0     4
# Gujarat                          0    2242         144       0     0
# Haryana                         44    1427           0       0     0
# Himachal Pradesh                 0     726           7       0     0
# ...

# %%
df_2.plot(kind='bar',stacked=True, figsize = (16,8));

# %%
#Answer-- Uttar pradesh

# %% [markdown]
# **Q2: Which Crop is seen in High frequency and when and where is it growth in India**

# %%
data_explorer["Crop"].value_counts()[:5]
# Out:
# Crop
# Rice                 15082
# Maize                13787
# Moong(Green Gram)    10106
# Urad                  9710
# Sesamum               8821
# Name: count, dtype: int64

# %%
rice_df= data_explorer[data_explorer["Crop"]=="Rice"]
print(rice_df.shape)
rice_df[:3]
# Out:
# (15082, 8)
#                      State_Name District_Name  Crop_Year       Season  Crop  \
# 2   Andaman and Nicobar Islands      NICOBARS       2000  Kharif       Rice
# 12  Andaman and Nicobar Islands      NICOBARS       2001  Kharif       Rice
# 18  Andaman and Nicobar Islands      NICOBARS       2002  Kharif       Rice
#
#      Area  Production     Zones
# 2   102.0      321.00  No Value
# 12   83.0      300.00  No Value
# 18  189.2      510.84  No Value

# %%
plt.figure(figsize=(18,10))
sns.barplot(x="Season",y="Production",data=rice_df);
plt.title('Season vs Production')
# Out:
# Text(0.5, 1.0, 'Season vs Production')

# %%
plt.figure(figsize=(13,10))
sns.barplot(x="State_Name",y="Production",data=rice_df)
plt.xticks(rotation=90)
plt.show()

# %%
top_rice_pro_dis = rice_df.groupby("District_Name")["Production"].sum().reset_index().sort_values(
    by='Production', ascending=False)
top_rice_pro_dis[:10]

sum_max = top_rice_pro_dis["Production"].sum()

top_rice_pro_dis["percent_of_pro"] = top_rice_pro_dis["Production"].map(lambda x: x / sum_max) * 100

top_rice_pro_dis[:10]
# Out:
#       District_Name  Production  percent_of_pro
# 58        BARDHAMAN  34239976.0        2.132707
# 374  MEDINIPUR WEST  29192719.0        1.818328
# 612   WEST GODAVARI  27845309.0        1.734402
# 169   EAST GODAVARI  24690929.0        1.537925
# 494         SANGRUR  24448000.0        1.522794
# 325         KRISHNA  20280606.0        1.263219
# 90          BIRBHUM  19753571.0        1.230391
# 347        LUDHIANA  18950000.0        1.180339
# 386     MURSHIDABAD  18403217.0        1.146282
# 214          GUNTUR  18245831.0        1.136479

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="District_Name",y="Production",data=top_rice_pro_dis[:10])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x="Crop_Year",y="Production",data=rice_df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.jointplot(x="Area",y="Production",data=rice_df,kind="reg")

# %%
#Answers
#1. Rice is grow heavily when we look the frequency of crops in India
#2. Rice needs Winter for it mature
#3. Statewise Punjab dominates in rice production
#4. District wise its BARDHAMAN, MEEDINIPUR WEST and WEST GODAVARI which contributes to total rice production.
#5. Yearwise 2014 is the year when production reached the peak production
#6. Correlation between Area And Production shows high Production is directly

# %% [markdown]
# **Which states ranks high in area wise crop production in India? Substantiate with facts and Figures?**

# %%
df = data_explorer.groupby(by='State_Name')['Area'].sum().reset_index().sort_values(by='Area',ascending=False)
df.head()

fig,ax = plt.subplots(figsize=(25,10))
sns.barplot(x=df.State_Name.head(10),y=df.Area.head(10))
plt.title('Agriculture Area Distribution-India')
df.head(10)
# Out:
#         State_Name          Area
# 30   Uttar Pradesh  4.336223e+08
# 16  Madhya Pradesh  3.297913e+08
# 17     Maharashtra  3.221860e+08
# 25       Rajasthan  2.687882e+08
# 32     West Bengal  2.154030e+08
# 14       Karnataka  2.029086e+08
# 9          Gujarat  1.549261e+08
# 1   Andhra Pradesh  1.315073e+08
# 4            Bihar  1.282695e+08
# 24          Punjab  1.267152e+08

# %%
df = data_explorer.groupby(by='State_Name')['Area'].sum().reset_index().sort_values(by='Area',ascending=False)
df.head(5)

fig, ax = plt.subplots(figsize=(25,30), sharey='col')
count = 1

for state in df.State_Name.unique():
    plt.subplot(len(df.State_Name.unique()),1,count)
    sns.lineplot(x=data_explorer[data_explorer.State_Name==state]['Crop_Year'],y=data_explorer[data_explorer.State_Name==state]['Production'], ci=None)
    plt.subplots_adjust(hspace=0.6)
    plt.title(state)
    count+=1;
# Out:
# C:\Users\com-tech computer\AppData\Local\Temp\ipykernel_5200\1397776750.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=data_explorer[data_explorer.State_Name==state]['Crop_Year'],y=data_explorer[data_explorer.State_Name==state]['Production'], ci=None)
# C:\Users\com-tech computer\AppData\Local\Temp\ipykernel_5200\1397776750.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=data_explorer[data_explorer.State_Name==state]['Crop_Year'],y=data_explorer[data_explorer.State_Name==state]['Production'], ci=None)
# C:\Users\com-tech computer\AppData\Local\Temp\ipykernel_5200\1397776750.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=data_explorer[data_explorer.State_Name==state]['Crop_Year'],y=data_explorer[data_explorer.State_Name==state]['Production'], ci=None)
# ...

# %%
#Answers
#1. Top cultivating states based on the Cultivation Area are: Uttar Pradesh, Madhya Pradesh and Maharashtra
#2. Yearwise Statues of these States:
#a. UP: High Production was seen in 2005 and after that it'been reducing gradually
#b. MP: 1998 showed a high production and then  there wass gradual reduction but it picked up and 2012 also showed a peak in Production
#c. Maharastra: Production went down drastically in 2006 and again the level went up and hit a high peak after 2007
#d. Rajasthan: the production hit all the time low in the year 2002 and then picked up by 2010
#e. West Bengal: The production hit a peak around 2006 but it has a low after 2007 and nevel recovered back.

# %% [markdown]
# **Q4: Discuss the top crops grown in Northern parts of India?**

# %%
data_explorer.Zones.value_counts()
# Out:
# Zones
# South Zone    43939
# North Zone    42593
# East Zone     41995
# NE Zone       32972
# West Zone     32927
# Union Terr    28284
# No Value      19651
# Name: count, dtype: int64

# %%
North_zone = data_explorer[(data_explorer["Zones"] == 'North Zone')]
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x=North_zone.State_Name, y=North_zone.Production)
plt.xticks(rotation=75);
plt.yscale('log')
plt.title('Northern-Zone Production')

North_zone.groupby(by='State_Name')['Production'].sum().reset_index().sort_values(by='Production', ascending=False)
# Out:
#            State_Name    Production
# 4       Uttar Pradesh  3.234493e+09
# 3              Punjab  5.863850e+08
# 1             Haryana  3.812739e+08
# 2  Jammu and Kashmir   1.329102e+07
# 0          Chandigarh  6.395650e+04

# %%
df3 = North_zone.groupby(by='Crop')['Production'].sum().reset_index().sort_values(by='Production', ascending=False).head(10)

fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(x=df3.Crop, y=df3.Production)
plt.xticks(rotation=75);
plt.yscale('log')
plt.title('North Zone Crops vs Production')
# Out:
# Text(0.5, 1.0, 'North Zone Crops vs Production')

# %%
#Answers:
#1. Production wise top states of North Zone are:
#-Punjab
#-UP
#2. Top crops of these states are:
#Sugarcane
#Wheat
#Rice

# %% [markdown]
# **Interfernce and Conclusion**

# %%
#We started with 22246091 samples with 7 columns.Production variable had 3730 missing values which has dropped and working datasets has 242361 sample size .
#also checked for multicollinearity of variables using heatmap.
